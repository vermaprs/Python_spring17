# %% [markdown]
# # Q1_Part 1

# %%
import pandas as pd

# %% [markdown]
# # import data from vehicle collision csv file

# %%
df = pd.read_csv('/Users/prashantverma/Documents/PythonBackup/Data/vehicle_collisions.csv')
df.shape
df.head()
# Out:
#    UNIQUE KEY    DATE  TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20    QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20       NaN       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21  BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30  BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33       NaN       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#         ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# 0       ...         SPORT UTILITY/STATION WAGON                NaN
# ...

# %% [markdown]
# # create dataframe for the result

# %%
from pandas import Series, DataFrame
dfResult = DataFrame()

# %% [markdown]
# # Filter the data for the year '2016'

# %%
df2016 = df[df['DATE'].apply(lambda x: x.split('/')[2] == '16')]
df2016.head()
df2016.shape
# Out:
# (227605, 29)

# %% [markdown]
#  # Filter the data for ManHattan

# %%
df_Manhattan = df2016[df2016.BOROUGH == 'MANHATTAN']
df_Manhattan.head()
# Out:
#         UNIQUE KEY    DATE  TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 217539     3374565  1/1/16  0:01  MANHATTAN   10022.0  40.760223 -73.967462
# 217541     3363408  1/1/16  0:01  MANHATTAN   10035.0  40.805057 -73.939034
# 217542     3364610  1/1/16  0:05  MANHATTAN   10035.0  40.799258 -73.939050
# 217543     3363371  1/1/16  0:15  MANHATTAN   10011.0  40.738552 -73.999682
# 217549     3370573  1/1/16  0:51  MANHATTAN   10040.0  40.863572 -73.926012
#
#                          LOCATION   ON STREET NAME CROSS STREET NAME  \
# 217539   (40.7602226, -73.967462)   EAST 57 STREET          3 AVENUE
# 217541  (40.8050573, -73.9390342)  EAST 125 STREET       PARK AVENUE
# 217542  (40.7992577, -73.9390504)         3 AVENUE   EAST 118 STREET
# 217543   (40.738552, -73.9996824)         7 AVENUE    WEST 14 STREET
# 217549  (40.8635725, -73.9260124)   SHERMAN AVENUE    DYCKMAN STREET
#
#              ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# ...

# %% [markdown]
# # Filter the data for 'NYC'

# %%
dfResult['NYC'] = df2016['DATE'].apply(lambda x: int(x.split('/')[0]))
dfResult.head()
# Out:
#         NYC
# 217539    1
# 217540    1
# 217541    1
# 217542    1
# 217543    1

# %% [markdown]
# # Count data for 'NYC' on month Basis

# %%
dfResult = dfResult.apply(pd.value_counts, sort=False)
dfResult.sort_index()
dfResult
# Out:
#       NYC
# 1   18101
# 2   15985
# 3   18471
# 4   18331
# 5   20052
# 6   19433
# 7   19867
# 8   19678
# 9   19492
# 10  19666
# 11  19315
# 12  19214

# %%
dfResult['ManHattan'] = df_Manhattan['DATE'].apply(lambda x: int(x.split('/')[0]))
dfResult.head()
# Out:
#         NYC  ManHattan
# 217539    1        1.0
# 217540    1        NaN
# 217541    1        1.0
# 217542    1        1.0
# 217543    1        1.0

# %% [markdown]
# # Count data for 'ManHattan' on month Basis

# %%
Result = dfResult.apply(pd.value_counts, sort=False)
res = DataFrame()
res = Result.sort_index()
res
# Out:
#       NYC  ManHattan
# 1   18101       3178
# 2   15985       3195
# 3   18471       3479
# 4   18331       3540
# 5   20052       3432
# 6   19433       2956
# 7   19867       3055
# 8   19678       2844
# 9   19492       2744
# 10  19666       2831
# 11  19315       2838
# 12  19214       2634

# %% [markdown]
# # Calculate Percentage between Manhattan & NYC

# %%
res['Percentage'] = res['ManHattan'] / res['NYC']
res
# Out:
#       NYC  ManHattan  Percentage
# 1   18101       3178    0.175570
# 2   15985       3195    0.199875
# 3   18471       3479    0.188349
# 4   18331       3540    0.193115
# 5   20052       3432    0.171155
# 6   19433       2956    0.152112
# 7   19867       3055    0.153773
# 8   19678       2844    0.144527
# 9   19492       2744    0.140776
# 10  19666       2831    0.143954
# 11  19315       2838    0.146932
# 12  19214       2634    0.137088

# %% [markdown]
# # Convert Month format from Digit to Letters

# %%
import datetime
res.rename(index=lambda x: datetime.datetime.strptime(str(x),'%m').strftime('%d/%b/%Y').split('/')[1])
# Out:
#        NYC  ManHattan  Percentage
# Jan  18101       3178    0.175570
# Feb  15985       3195    0.199875
# Mar  18471       3479    0.188349
# Apr  18331       3540    0.193115
# May  20052       3432    0.171155
# Jun  19433       2956    0.152112
# Jul  19867       3055    0.153773
# Aug  19678       2844    0.144527
# Sep  19492       2744    0.140776
# Oct  19666       2831    0.143954
# Nov  19315       2838    0.146932
# Dec  19214       2634    0.137088
