# %% [markdown]
# # Q2_Part1

# %%
import pandas as pd

# %% [markdown]
# # import data from employee compensation csv file

# %%
df = pd.read_csv('Data/employee_compensation.csv')
df.shape
df.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
#                                 Union Job Family Code           Job Family  \
# 0  Plumbers and Pipefitters, Local 38            7300     Journeyman Trade
# 1    SEIU - Miscellaneous, Local 1021            2600       Dietary & Food
# 2   Members of Boards and Commissions            0900           Management
# 3    SEIU - Miscellaneous, Local 1021            8100        Legal & Court
# 4    SEIU - Miscellaneous, Local 1021            9900  Public Service Aide
#
#           ...         Employee Identifier  Salaries  Overtime  Other Salaries  \
# 0         ...                       52206  98528.52      0.00         3955.59
# 1         ...                       52950  69169.82    755.02         4179.08
# 2         ...                       33958    200.00      0.00            0.00
# 3         ...                       33073   1783.00      0.00            0.00
# 4         ...                       15849   1102.50      0.00            0.00
#
#    Total Salary  Retirement  Health/Dental  Other Benefits  Total Benefits  \
# 0     102484.11    20142.55       12918.24         8371.76        41432.55
# 1      74103.92    15641.92       12499.30         5669.02        33810.24
# 2        200.00        0.00          51.45           15.83           67.28
# 3       1783.00      325.05         257.23          153.85          736.13
# 4       1102.50        0.00         538.82           85.36          624.18
#
#    Total Compensation
# 0           143916.66
# 1           107914.16
# 2              267.28
# 3             2519.13
# 4             1726.68
#
# [5 rows x 22 columns]

# %% [markdown]
# # Create empty DataFrames

# %%
from pandas import Series, DataFrame
dfGroup = DataFrame()
dfRequired = DataFrame()
dfResult = DataFrame()

# %% [markdown]
# # Group By Column 'Organization Group', 'Department' group and find mean

# %%
dfGroup = df.groupby(['Organization Group', 'Department']).mean().reset_index()
dfGroup.head()
# Out:
#      Organization Group           Department         Year  \
# 0      Community Health        Public Health  2014.526637
# 1  Culture & Recreation  Academy of Sciences  2014.495726
# 2  Culture & Recreation      Arts Commission  2014.500000
# 3  Culture & Recreation     Asian Art Museum  2014.527190
# 4  Culture & Recreation     Fine Arts Museum  2014.370082
#
#    Organization Group Code  Union Code  Employee Identifier      Salaries  \
# 0                      4.0  546.874501         27581.586761  64439.933599
# 1                      5.0   39.000000         35759.222222  65104.676068
# 2                      5.0  594.867978         27780.404494  65770.560000
# 3                      5.0  686.294562         28009.910876  46259.343520
# 4                      5.0  739.807411         28558.108417  27374.663051
#
#       Overtime  Other Salaries  Total Salary    Retirement  Health/Dental  \
# 0  1537.375993     4456.426791  70433.736383  12293.745146    8272.922619
# 1  4110.572308     8774.288803  77989.537179  13221.395299    9856.260769
# 2     0.000000      194.028258  65964.588258  12715.266180    9920.138483
# 3  1894.722840     1731.173112  49885.239471   8870.477281    8371.461511
# 4  3374.973577     1126.805782  31876.442411   4257.649250    5395.513632
#
#    Other Benefits  Total Benefits  Total Compensation
# 0     5189.785992    25756.453757        96190.190140
# 1     6252.534444    29330.190513       107319.727692
# 2     5739.604466    28375.009129        94339.597388
# 3     4274.341798    21516.280589        71401.520060
# 4     2675.834602    12328.997484        44205.439895

# %%
dfRequired = dfGroup[['Organization Group', 'Department','Total Compensation']]
dfRequired.head()
# Out:
#      Organization Group           Department  Total Compensation
# 0      Community Health        Public Health        96190.190140
# 1  Culture & Recreation  Academy of Sciences       107319.727692
# 2  Culture & Recreation      Arts Commission        94339.597388
# 3  Culture & Recreation     Asian Art Museum        71401.520060
# 4  Culture & Recreation     Fine Arts Museum        44205.439895

# %% [markdown]
# # sort from max to min based on total compensation

# %%
dfResult = dfRequired.sort_values(['Organization Group','Total Compensation'], ascending=[True,False])
dfResult.head()
# Out:
#      Organization Group           Department  Total Compensation
# 0      Community Health        Public Health        96190.190140
# 5  Culture & Recreation          Law Library       188424.362222
# 1  Culture & Recreation  Academy of Sciences       107319.727692
# 2  Culture & Recreation      Arts Commission        94339.597388
# 8  Culture & Recreation         War Memorial        76250.068022

# %% [markdown]
# # Save data to csv file

# %%
dfResult.to_csv('Q2_Part1.csv',index = False, sep=',')
