# %% [markdown]
# # Q1_Part2

# %%
import pandas as pd

# %% [markdown]
# # import data from vehicle collision csv file

# %%
df = pd.read_csv('Data/vehicle_collisions.csv')
df.shape
df.head()
# Out:
#    UNIQUE KEY    DATE  TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20    QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20       NaN       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21  BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30  BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33       NaN       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#         ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# 0       ...         SPORT UTILITY/STATION WAGON                NaN
# 1       ...                   PASSENGER VEHICLE                NaN
# 2       ...                   PASSENGER VEHICLE            UNKNOWN
# 3       ...                                 BUS  PASSENGER VEHICLE
# 4       ...                             UNKNOWN  PASSENGER VEHICLE
#
#    VEHICLE 3 TYPE  VEHICLE 4 TYPE  VEHICLE 5 TYPE  \
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
# 3             NaN             NaN             NaN
# 4             NaN             NaN             NaN
#
#               VEHICLE 1 FACTOR  VEHICLE 2 FACTOR  VEHICLE 3 FACTOR  \
# 0  TRAFFIC CONTROL DISREGARDED               NaN               NaN
# 1               ANIMALS ACTION               NaN               NaN
# 2              FATIGUED/DROWSY       UNSPECIFIED               NaN
# 3           LOST CONSCIOUSNESS               NaN               NaN
# 4                  UNSPECIFIED       UNSPECIFIED               NaN
#
#    VEHICLE 4 FACTOR VEHICLE 5 FACTOR
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Create empty DataFrames

# %%
from pandas import Series, DataFrame
dfGroup = DataFrame()
dfResult = DataFrame()

# %% [markdown]
# # Group By Column 'Borough', to calculate the count

# %%
dfGroup = df.groupby('BOROUGH').count()

# %%
dfGroup
# Out:
#                UNIQUE KEY    DATE    TIME  ZIP CODE  LATITUDE  LONGITUDE  \
# BOROUGH
# BRONX               46124   46124   46124     46124     41789      41789
# BROOKLYN           104961  104961  104961    104957     96155      96155
# MANHATTAN           83602   83602   83602     83600     77163      77163
# QUEENS              89655   89655   89655     89600     81072      81072
# STATEN ISLAND       14048   14048   14048     14048     12819      12819
#
#                LOCATION  ON STREET NAME  CROSS STREET NAME  OFF STREET NAME  \
# BOROUGH
# BRONX             41789           37903              37903             7977
# BROOKLYN          96155           90248              90248            14696
# MANHATTAN         77163           73613              73614             9975
# QUEENS            81072           75680              75680            13858
# STATEN ISLAND     12819           12191              12191             1855
#
#                      ...         VEHICLE 1 TYPE  VEHICLE 2 TYPE  \
# BOROUGH              ...
# BRONX                ...                  45599           36972
# BROOKLYN             ...                 104174           86799
# MANHATTAN            ...                  82801           69483
# QUEENS               ...                  89140           76178
# STATEN ISLAND        ...                  13943           11600
#
#                VEHICLE 3 TYPE  VEHICLE 4 TYPE  VEHICLE 5 TYPE  \
# BOROUGH
# BRONX                    2587             625             173
# BROOKLYN                 6592            1612             461
# MANHATTAN                2525             501             129
# QUEENS                   5918            1420             314
# STATEN ISLAND             924             165              32
#
#                VEHICLE 1 FACTOR  VEHICLE 2 FACTOR  VEHICLE 3 FACTOR  \
# BOROUGH
# BRONX                     45844             39298              2706
# BROOKLYN                 104096             89988              6849
# MANHATTAN                 82737             71940              2661
# QUEENS                    89145             78603              6132
# STATEN ISLAND             13985             12207               954
#
#                VEHICLE 4 FACTOR  VEHICLE 5 FACTOR
# BOROUGH
# BRONX                       651               178
# BROOKLYN                   1688               476
# MANHATTAN                   544               145
# QUEENS                     1474               329
# STATEN ISLAND               176                35
#
# [5 rows x 28 columns]

# %% [markdown]
# # Store result in a new DataFrame and assign data

# %%
dfResult['ONE_VEHICLE_INVOLVED'] = dfGroup['VEHICLE 1 TYPE'] - dfGroup['VEHICLE 2 TYPE']

dfResult['TWO_VEHICLES_INVOLVED'] = dfGroup['VEHICLE 2 TYPE'] - dfGroup['VEHICLE 3 TYPE']

dfResult['THREE_VEHICLES_INVOLVED'] = dfGroup['VEHICLE 3 TYPE'] - dfGroup['VEHICLE 4 TYPE']

dfResult['MORE_VEHICLES_INVOLVED'] = dfGroup['VEHICLE 4 TYPE'] +  dfGroup['VEHICLE 5 TYPE']

dfResult.head()
# Out:
#                ONE_VEHICLE_INVOLVED  TWO_VEHICLES_INVOLVED  \
# BOROUGH
# BRONX                          8627                  34385
# BROOKLYN                      17375                  80207
# MANHATTAN                     13318                  66958
# QUEENS                        12962                  70260
# STATEN ISLAND                  2343                  10676
#
#                THREE_VEHICLES_INVOLVED  MORE_VEHICLES_INVOLVED
# BOROUGH
# BRONX                             1962                     798
# BROOKLYN                          4980                    2073
# MANHATTAN                         2024                     630
# QUEENS                            4498                    1734
# STATEN ISLAND                      759                     197

# %%
dfResult['BOROUGH'] = dfGroup.index
dfResult = dfResult[['BOROUGH','ONE_VEHICLE_INVOLVED','TWO_VEHICLES_INVOLVED','THREE_VEHICLES_INVOLVED','MORE_VEHICLES_INVOLVED']]
dfResult
# Out:
#                      BOROUGH  ONE_VEHICLE_INVOLVED  TWO_VEHICLES_INVOLVED  \
# BOROUGH
# BRONX                  BRONX                  8627                  34385
# BROOKLYN            BROOKLYN                 17375                  80207
# MANHATTAN          MANHATTAN                 13318                  66958
# QUEENS                QUEENS                 12962                  70260
# STATEN ISLAND  STATEN ISLAND                  2343                  10676
#
#                THREE_VEHICLES_INVOLVED  MORE_VEHICLES_INVOLVED
# BOROUGH
# BRONX                             1962                     798
# BROOKLYN                          4980                    2073
# MANHATTAN                         2024                     630
# QUEENS                            4498                    1734
# STATEN ISLAND                      759                     197

# %% [markdown]
# # Save data to csv file

# %%
dfResult.to_csv('Q1_Part2.csv', index=False, sep=',')
